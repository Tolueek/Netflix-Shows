# %%
import pandas as pd

df = pd.read_csv('Netflix_shows_movies.csv')

# %%
print(df.isnull().sum())
# Out:
# show_id            0
# type               0
# title              0
# director        1969
# cast             570
# country          476
# date_added        11
# release_year       0
# rating            10
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
df.fillna({'column_name': 'default_value'}, inplace=True)

# %%
df.dropna(inplace=True)

# %%
print(df.describe())
print(df.info())
# Out:
#             show_id  release_year
# count  3.774000e+03   3774.000000
# mean   7.510908e+07   2012.087440
# std    1.341114e+07      9.566944
# min    2.477470e+05   1942.000000
# 25%    7.027581e+07   2011.000000
# 50%    8.014732e+07   2016.000000
# 75%    8.024067e+07   2017.000000
# max    8.123573e+07   2020.000000
# <class 'pandas.core.frame.DataFrame'>
# Index: 3774 entries, 0 to 6213
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       3774 non-null   int64
#  1   type          3774 non-null   object
#  2   title         3774 non-null   object
#  3   director      3774 non-null   object
#  4   cast          3774 non-null   object
#  5   country       3774 non-null   object
#  6   date_added    3774 non-null   object
#  7   release_year  3774 non-null   int64
#  8   rating        3774 non-null   object
#  9   duration      3774 non-null   object
#  10  listed_in     3774 non-null   object
# ...

# %%
# Count the occurrences of each title
title_counts = df.groupby('title').size().reset_index(name='count')

# Sort the titles by frequency in descending order
title_counts_sorted = title_counts.sort_values(by='count', ascending=False)

# Display the top 10 most frequent titles
print(title_counts_sorted.head(10))
# Out:
#             title  count
# 3332  The Silence      3
# 876           Don      2
# 3561  Us and Them      2
# 905         Drive      2
# 2267      One Day      2
# 3321    The Saint      2
# 502   Blood Money      2
# 3225   The Lovers      2
# 613        Carrie      2
# 3431        Tiger      2

# %%
# Count the occurrences of each title
title_counts = df.groupby('title').size().reset_index(name='count')

# Sort by the count of views in descending order
title_counts_sorted = title_counts.sort_values(by='count', ascending=False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(data=top_titles, x='count', y='title', palette='viridis')
plt.title('Top 10 Most Watched Titles')
plt.xlabel('View Count')
plt.ylabel('Title')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/_z/xdbhcd_n5c380kbc115zj3l40000gn/T/ipykernel_1009/2352478383.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_titles, x='count', y='title', palette='viridis')

# %%
sns.histplot(df['rating'], bins=10, kde=True, color='blue')
plt.title('Ratings Distribution')
plt.xlabel('Ratings')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
# Count ratings
rating_counts = df['rating'].value_counts().reset_index()
rating_counts.columns = ['rating', 'count']

# Plot the distribution
sns.barplot(data=rating_counts, x='count', y='rating', palette='coolwarm')
plt.title('Ratings Distribution')
plt.xlabel('Frequency')
plt.ylabel('Rating')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/_z/xdbhcd_n5c380kbc115zj3l40000gn/T/ipykernel_1009/294889857.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=rating_counts, x='count', y='rating', palette='coolwarm')

# %%
# Select the top 10 most frequent titles
top_titles = title_counts_sorted.head(10)

# Plot the data using Seaborn
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(data=top_titles, x='count', y='title', palette='viridis')
plt.title('Top 10 Most Frequent Titles')
plt.xlabel('Frequency')
plt.ylabel('Title')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/_z/xdbhcd_n5c380kbc115zj3l40000gn/T/ipykernel_1009/2662396940.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_titles, x='count', y='title', palette='viridis')

# %%
df.to_csv('cleaned_netflix_data.csv', index=False)
